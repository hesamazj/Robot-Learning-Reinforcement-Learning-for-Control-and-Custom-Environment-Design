# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
import pygame
import cv2
from stable_baselines3 import PPO
# Out:
# 2023-10-11 16:47:15.680667: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-11 16:47:15.704411: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-11 16:47:15.704445: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-11 16:47:15.704463: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-11 16:47:15.709674: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-11 16:47:16.268502: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
class GridworldEnv(gym.Env):
    def __init__(self, grid_size):
        self.grid_size = grid_size
        self.grid = np.zeros((grid_size, grid_size), dtype=int)
        self.agent_pos = None
        self.apple_pos = None
        self.plate_pos = None
        self.apple_agent = False    
        self.agent_plate = False
        self.done = False
        self.reward = 0

        self.action_space = gym.spaces.Discrete(4)  # 4 possible actions: Up, Down, Left, Right
        self.observation_space = gym.spaces.Box(low=0, high=1, shape=(grid_size, grid_size), dtype=int)

        pygame.init()
        self.screen_size = (400, 400) 
        self.screen = pygame.display.set_mode(self.screen_size)
        self.apple_img = pygame.image.load("apple.png")
        self.plate_img = pygame.image.load("plate.png")
        self.robot_img = pygame.image.load("robot.png")

        # Scale apple and plate images to fit grid cells
        cell_size = self.screen_size[0] // grid_size
        self.apple_img = pygame.transform.scale(self.apple_img, (cell_size, cell_size))
        self.plate_img = pygame.transform.scale(self.plate_img, (cell_size, cell_size))
        self.robot_img = pygame.transform.scale(self.robot_img, (cell_size, cell_size))
        self.clock = pygame.time.Clock()
        self.target_fps = 3 



    def reset(self):

        # Randomly place the agent, apple, and plate in the grid
        self.agent_pos = np.random.randint(0, self.grid_size, size=2)
        self.apple_pos = np.random.randint(0, self.grid_size, size=2)
        while np.array_equal(self.apple_pos, self.agent_pos):
            self.apple_pos = np.random.randint(0, self.grid_size, size=2)
        self.plate_pos = np.random.randint(0, self.grid_size, size=2)
        while np.array_equal(self.plate_pos, self.agent_pos) or np.array_equal(self.plate_pos, self.apple_pos):
            self.plate_pos = np.random.randint(0, self.grid_size, size=2)

        self.grid = np.zeros((self.grid_size, self.grid_size), dtype=int)
        self.grid[tuple(self.agent_pos)] = 1
        self.grid[tuple(self.apple_pos)] = 2
        self.grid[tuple(self.plate_pos)] = 3

        self.done = False
        self.apple_agent = False
        self.agent_plate = False
        
        self.reward = 0
        return self.grid.copy()

    def step(self, action):
        if self.done:
            raise ValueError("Episode is already done. Please reset the environment.")

        movements = {
            0: (-1, 0),  # Up
            1: (1, 0),   # Down
            2: (0, -1),  # Left
            3: (0, 1)    # Right
        }
        agent_new_pos = tuple(self.agent_pos + np.array(movements[int(action)]))

        # Check for boundary constraints
        if 0 <= agent_new_pos[0] < self.grid_size and 0 <= agent_new_pos[1] < self.grid_size:
            if self.apple_agent:
                self.grid[tuple(self.apple_pos)] = 0 
            if self.agent_plate:
                self.grid[tuple(self.plate_pos)] = 3
                
            self.grid[tuple(self.agent_pos)] = 0
            self.agent_pos = np.array(agent_new_pos)
            self.grid[tuple(self.agent_pos)] = 1



        if np.array_equal(self.agent_pos, self.plate_pos):
            self.agent_plate = True
        if np.array_equal(self.agent_pos, self.apple_pos):
            self.apple_agent = True

        if self.apple_agent:

        # Check if the agent has successfully completed the task
            if np.array_equal(self.agent_pos, self.plate_pos):

                self.done = True
                self.reward = 100  

        return self.grid.copy(), self.reward, self.done, {}


    def render(self):
        self.screen.fill((255, 255, 255)) 
        cell_size = self.screen_size[0] // self.grid_size

        for row in range(self.grid_size):
            for col in range(self.grid_size):
                cell_value = self.grid[row, col]
                x, y = col * cell_size, row * cell_size

                if cell_value == 1:
                    self.screen.blit(self.robot_img, (x, y))  
                elif cell_value == 2:
                    self.screen.blit(self.apple_img, (x, y))  
                elif cell_value == 3:
                    self.screen.blit(self.plate_img, (x, y))  
                else:
                    color = (255, 255, 255)  # White for empty

                pygame.draw.rect(self.screen, (0, 0, 0), (x, y, cell_size, cell_size), 1)

        pygame.display.flip()
        self.clock.tick(self.target_fps)

    def close(self):
        pass

# %% [markdown]
# We visualize the environment in the cell below:

# %%
grid_size = 5
env = GridworldEnv(grid_size)
observation = env.reset()
done = False


fourcc = cv2.VideoWriter_fourcc(*'XVID')
video_writer = cv2.VideoWriter('gridworld_video.avi', fourcc, 3, env.screen_size)


for i in range(10000):    
    action = env.action_space.sample()
    observation, reward, done, _ = env.step(action)
    env.render()
    pygame.event.get()  
    frame = pygame.surfarray.array3d(env.screen)
    frame = np.transpose(frame, (1, 0, 2)) 
    video_writer.write(frame) 

    if done:
        break

video_writer.release()


pygame.quit()

# %% [markdown]
# Trainning PPO with the sparse reward:

# %%
# Create a gym environment
gridworld_env = GridworldEnv(grid_size=5)
pygame.quit()
# Create and train the PPO agent
model = PPO("MlpPolicy", gridworld_env, verbose=1,learning_rate=0.0001,gamma= 0.99,tensorboard_log=
            "ppo_gridworld_tensorboard/")

model.learn(total_timesteps=100000,tb_log_name='sparse')  # Adjust the number of timesteps as needed

# Save the trained model
model.save("ppo_gridworld")
del model  # Delete trained model to demonstrate loading
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ppo_gridworld_tensorboard/sparse_1
# libpng warning: iCCP: known incorrect sRGB profile
# /home/hesam/anaconda3/envs/mujoco_env/lib/python3.9/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 158      |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    fps             | 3578     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 135          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 2231         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0030164951 |
# |    clip_fraction        | 0.00444      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000291     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 384          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00366     |
# |    value_loss           | 467          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 120           |
# |    ep_rew_mean          | 100           |
# | time/                   |               |
# |    fps                  | 2031          |
# |    iterations           | 3             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00026294144 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | -0.00165      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 130           |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00135      |
# |    value_loss           | 659           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1868         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0009524565 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00874      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 346          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 725          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 103           |
# |    ep_rew_mean          | 100           |
# | time/                   |               |
# |    fps                  | 1835          |
# |    iterations           | 5             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00057830085 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.000891     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 255           |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00201      |
# |    value_loss           | 707           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.2         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1841         |
# |    iterations           | 6            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0006801699 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00318     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 354          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 715          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.1         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1809         |
# |    iterations           | 7            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0022014738 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00521     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 149          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00402     |
# |    value_loss           | 494          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.3         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1709         |
# |    iterations           | 8            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0007134831 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00845     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 310          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 626          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.9         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1732         |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0035007591 |
# |    clip_fraction        | 0.00557      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00359     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 159          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00498     |
# |    value_loss           | 421          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.9         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1661         |
# |    iterations           | 10           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0013488107 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.000581    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 246          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 534          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.5         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1588         |
# |    iterations           | 11           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0033947485 |
# |    clip_fraction        | 0.0022       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00116     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 267          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00528     |
# |    value_loss           | 444          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.1         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1525         |
# |    iterations           | 12           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0017607526 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00157     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 344          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00302     |
# |    value_loss           | 507          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.1        |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 1545        |
# |    iterations           | 13          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.002526064 |
# |    clip_fraction        | 0.000488    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00215    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 140         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00319    |
# |    value_loss           | 391         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 79.6          |
# |    ep_rew_mean          | 100           |
# | time/                   |               |
# |    fps                  | 1510          |
# |    iterations           | 14            |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00046325405 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.000396     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 254           |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00143      |
# |    value_loss           | 502           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.6         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1474         |
# |    iterations           | 15           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0008338501 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000851    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 120          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 416          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.5         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1456         |
# |    iterations           | 16           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0017136936 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000454    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 178          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 379          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.7         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1446         |
# |    iterations           | 17           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0027872764 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000378    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 233          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 384          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.1         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1428         |
# |    iterations           | 18           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0058792904 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000235    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 93.7         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00371     |
# |    value_loss           | 260          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 82.3          |
# |    ep_rew_mean          | 100           |
# | time/                   |               |
# |    fps                  | 1402          |
# |    iterations           | 19            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00032256028 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | -0.000416     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 92.2          |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000736     |
# |    value_loss           | 305           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.6         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1395         |
# |    iterations           | 20           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0012802178 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00013     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 160          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 300          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.8        |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 1379        |
# |    iterations           | 21          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004726043 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.000162   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 82          |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00313    |
# |    value_loss           | 245         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 80.3          |
# |    ep_rew_mean          | 100           |
# | time/                   |               |
# |    fps                  | 1396          |
# |    iterations           | 22            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00018499148 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -0.000162     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 93.9          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000682     |
# |    value_loss           | 286           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.3         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1390         |
# |    iterations           | 23           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0075897146 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.000106    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 100          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00482     |
# |    value_loss           | 200          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1384         |
# |    iterations           | 24           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0031248948 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -6.9e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 117          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 209          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99.6         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1365         |
# |    iterations           | 25           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0025028945 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -3.23e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 89.9         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 157          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 98.3          |
# |    ep_rew_mean          | 100           |
# | time/                   |               |
# |    fps                  | 1348          |
# |    iterations           | 26            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00029207737 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | -1.56e-05     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 176           |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000691     |
# |    value_loss           | 295           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 91.8          |
# |    ep_rew_mean          | 100           |
# | time/                   |               |
# |    fps                  | 1357          |
# |    iterations           | 27            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00031062716 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | -2.68e-05     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 148           |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000665     |
# |    value_loss           | 280           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.8        |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 1364        |
# |    iterations           | 28          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.002305532 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -1.8e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 57.7        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 226         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.4        |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 1357        |
# |    iterations           | 29          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004751032 |
# |    clip_fraction        | 0.00391     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -2.52e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 44.7        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00319    |
# |    value_loss           | 146         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.8         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1363         |
# |    iterations           | 30           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0030670231 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -7.94e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 165          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00321     |
# |    value_loss           | 248          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93           |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1368         |
# |    iterations           | 31           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0006155361 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -2.38e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 127          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 257          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.5         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1373         |
# |    iterations           | 32           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0011073127 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -4.77e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 65.1         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000819    |
# |    value_loss           | 152          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.4        |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 1355        |
# |    iterations           | 33          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004898272 |
# |    clip_fraction        | 0.0043      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -1.18e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 73.8        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 182         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1363         |
# |    iterations           | 34           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0017518348 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -2.62e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 66.4         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 224          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1368         |
# |    iterations           | 35           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0022034617 |
# |    clip_fraction        | 0.00259      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -2.5e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 95.7         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 161          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.2         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1350         |
# |    iterations           | 36           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0014856791 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -7.27e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 103          |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 260          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 59.3          |
# |    ep_rew_mean          | 100           |
# | time/                   |               |
# |    fps                  | 1351          |
# |    iterations           | 37            |
# |    time_elapsed         | 56            |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 7.5014774e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | -8.82e-05     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 127           |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000507     |
# |    value_loss           | 268           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 54.4          |
# |    ep_rew_mean          | 100           |
# | time/                   |               |
# |    fps                  | 1349          |
# |    iterations           | 38            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00026531197 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | -5.36e-06     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 103           |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000536     |
# |    value_loss           | 262           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 59.9         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1340         |
# |    iterations           | 39           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0016184641 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -1.37e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 127          |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00169     |
# |    value_loss           | 234          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 65.1         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1330         |
# |    iterations           | 40           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0039374176 |
# |    clip_fraction        | 0.00342      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -4.53e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 106          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00379     |
# |    value_loss           | 192          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.2         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1326         |
# |    iterations           | 41           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0063822647 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -3.81e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 142          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00589     |
# |    value_loss           | 183          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 76.1         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1328         |
# |    iterations           | 42           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0017972453 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -1.07e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 101          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00304     |
# |    value_loss           | 194          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.3         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1332         |
# |    iterations           | 43           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0021711178 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 6.32e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 86.5         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 166          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81           |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1318         |
# |    iterations           | 44           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0011324415 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | -7.63e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 82.2         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 150          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90.1         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1321         |
# |    iterations           | 45           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0033076769 |
# |    clip_fraction        | 0.00083      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -1.35e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 109          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00361     |
# |    value_loss           | 206          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.5         |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1324         |
# |    iterations           | 46           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0007821971 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 6.74e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 80           |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000957    |
# |    value_loss           | 144          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1328         |
# |    iterations           | 47           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0008015181 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -2.62e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 77.1         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 179          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1328         |
# |    iterations           | 48           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0020276078 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -2.57e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 152          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 174          |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 109            |
# |    ep_rew_mean          | 100            |
# | time/                   |                |
# |    fps                  | 1325           |
# |    iterations           | 49             |
# |    time_elapsed         | 75             |
# |    total_timesteps      | 100352         |
# | train/                  |                |
# |    approx_kl            | 0.000104409264 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.31          |
# |    explained_variance   | -2.5e-06       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 50.2           |
# |    n_updates            | 480            |
# |    policy_gradient_loss | -0.000365      |
# |    value_loss           | 135            |
# --------------------------------------------

# %% [markdown]
# You may test the trained agent using sparse reward using the code below. It will visulaize the agent and the trajectories using pygame:

# %%
gridworld_env = GridworldEnv(grid_size=5)

model = PPO.load("ppo_gridworld")
# Test the trained model
obs = gridworld_env.reset()

while True:
    action, _states = model.predict(obs)
    obs, reward, done, _ = gridworld_env.step(action)
    gridworld_env.render()
    if done:
        break

pygame.quit()
print(reward)

gridworld_env.close()
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
# 100

# %% [markdown]
# __Reward Shaping__: In this part, we shaped the reward using the l1 norm distance between the agent and the apple until it finds the apple, and then we added the negative of the l1 norm distance between the agent and the plate as the new reward for the second phase of the episode. Finally, if the agent gets to the plate, it will get a rewrd of 100.

# %%
def l1distance(point1, point2):

    return np.linalg.norm(np.array(point1)-np.array(point2), ord=1)

# %%
class GridworldEnv(gym.Env):
    def __init__(self, grid_size):
        self.grid_size = grid_size
        self.grid = np.zeros((grid_size, grid_size), dtype=int)
        self.agent_pos = None
        self.apple_pos = None
        self.plate_pos = None
        self.apple_agent_dist = 5
        self.plate_agent_dist = 5
        self.apple_agent = False    
        self.agent_plate = False
        self.done = False
        self.reward = 0

        self.action_space = gym.spaces.Discrete(4)  # 4 possible actions: Up, Down, Left, Right
        self.observation_space = gym.spaces.Box(low=0, high=1, shape=(grid_size, grid_size), dtype=int)

        pygame.init()
        self.screen_size = (400, 400)  
        self.screen = pygame.display.set_mode(self.screen_size)
        self.apple_img = pygame.image.load("images/apple.png")
        self.plate_img = pygame.image.load("images/plate.png")
        self.robot_img = pygame.image.load("images/robot.png")

        cell_size = self.screen_size[0] // grid_size
        self.apple_img = pygame.transform.scale(self.apple_img, (cell_size, cell_size))
        self.plate_img = pygame.transform.scale(self.plate_img, (cell_size, cell_size))
        self.robot_img = pygame.transform.scale(self.robot_img, (cell_size, cell_size))
        self.clock = pygame.time.Clock()
        self.target_fps = 3 



    def reset(self):

        self.agent_pos = np.random.randint(0, self.grid_size, size=2)
        self.apple_pos = np.random.randint(0, self.grid_size, size=2)
        while np.array_equal(self.apple_pos, self.agent_pos):
            self.apple_pos = np.random.randint(0, self.grid_size, size=2)
        self.plate_pos = np.random.randint(0, self.grid_size, size=2)
        while np.array_equal(self.plate_pos, self.agent_pos) or np.array_equal(self.plate_pos, self.apple_pos):
            self.plate_pos = np.random.randint(0, self.grid_size, size=2)

        self.grid = np.zeros((self.grid_size, self.grid_size), dtype=int)
        self.grid[tuple(self.agent_pos)] = 1
        self.grid[tuple(self.apple_pos)] = 2
        self.grid[tuple(self.plate_pos)] = 3

        self.done = False
        self.apple_agent = False
        self.agent_plate = False
        
        self.reward = 0
        return self.grid.copy()

    def step(self, action):
        if self.done:
            raise ValueError("Episode is already done. Please reset the environment.")

        # Define movement actions
        movements = {
            0: (-1, 0),  # Up
            1: (1, 0),   # Down
            2: (0, -1),  # Left
            3: (0, 1)    # Right
        }

        agent_new_pos = tuple(self.agent_pos + np.array(movements[int(action)]))

        # Check for boundary constraints
        if 0 <= agent_new_pos[0] < self.grid_size and 0 <= agent_new_pos[1] < self.grid_size:
            if self.apple_agent:
                self.grid[tuple(self.apple_pos)] = 0 
            if self.agent_plate:
                self.grid[tuple(self.plate_pos)] = 3
                
            self.grid[tuple(self.agent_pos)] = 0
            self.agent_pos = np.array(agent_new_pos)
            self.grid[tuple(self.agent_pos)] = 1





        if np.array_equal(self.agent_pos, self.plate_pos):
            self.agent_plate = True
        if np.array_equal(self.agent_pos, self.apple_pos):
            self.apple_agent = True


        if not self.apple_agent:
            self.reward = -l1distance(self.agent_pos, self.apple_pos)/100
        else:
            self.reward += -l1distance(self.agent_pos, self.plate_pos)/100

            if np.array_equal(self.agent_pos, self.plate_pos):

                self.done = True
                self.reward += 100  
        


        return self.grid.copy(), self.reward, self.done, {}


    def render(self):
        self.screen.fill((255, 255, 255))  # Fill the screen with white
        cell_size = self.screen_size[0] // self.grid_size

        for row in range(self.grid_size):
            for col in range(self.grid_size):
                cell_value = self.grid[row, col]
                x, y = col * cell_size, row * cell_size

                if cell_value == 1:
                    self.screen.blit(self.robot_img, (x, y))  # Draw robot image
                elif cell_value == 2:
                    self.screen.blit(self.apple_img, (x, y))  # Draw apple image
                elif cell_value == 3:
                    self.screen.blit(self.plate_img, (x, y))  # Draw plate image
                else:
                    color = (255, 255, 255)  # White for empty

                pygame.draw.rect(self.screen, (0, 0, 0), (x, y, cell_size, cell_size), 1)

        pygame.display.flip()
        self.clock.tick(self.target_fps)

    def close(self):
        pass

# %% [markdown]
# Trainning the agent using PPO and the shaped reward:

# %%
gridworld_env = GridworldEnv(grid_size=5)
pygame.quit()

model = PPO("MlpPolicy", gridworld_env, verbose=1,learning_rate=0.0001,gamma= 0.99,tensorboard_log=
            "ppo_gridworld_tensorboard/")
model.learn(total_timesteps=100000,tb_log_name='Shaped')  

model.save("ppo_gridworld")
del model
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ppo_gridworld_tensorboard/Shaped_1
# libpng warning: iCCP: known incorrect sRGB profile
# /home/hesam/anaconda3/envs/mujoco_env/lib/python3.9/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | 33.5     |
# | time/              |          |
# |    fps             | 3706     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | 60.8         |
# | time/                   |              |
# |    fps                  | 2443         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0023710337 |
# |    clip_fraction        | 0.000537     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00496      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 341          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0043      |
# |    value_loss           | 685          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 104           |
# |    ep_rew_mean          | 41.5          |
# | time/                   |               |
# |    fps                  | 2135          |
# |    iterations           | 3             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00040678747 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0.00166       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 250           |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00168      |
# |    value_loss           | 727           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | 38.5         |
# | time/                   |              |
# |    fps                  | 2026         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0003670019 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0318       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 575          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 1.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 16.4         |
# | time/                   |              |
# |    fps                  | 1810         |
# |    iterations           | 5            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0016514516 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00141     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 514          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 879          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.8         |
# |    ep_rew_mean          | 11.7         |
# | time/                   |              |
# |    fps                  | 1596         |
# |    iterations           | 6            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0001415186 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00593      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.06e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000823    |
# |    value_loss           | 2.74e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99.7       |
# |    ep_rew_mean          | 1.75       |
# | time/                   |            |
# |    fps                  | 1542       |
# |    iterations           | 7          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00161364 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.056      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 384        |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00307   |
# |    value_loss           | 815        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.5         |
# |    ep_rew_mean          | 15.6         |
# | time/                   |              |
# |    fps                  | 1485         |
# |    iterations           | 8            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0016752861 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0425      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 306          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00333     |
# |    value_loss           | 854          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91          |
# |    ep_rew_mean          | 2.57        |
# | time/                   |             |
# |    fps                  | 1457        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.002432755 |
# |    clip_fraction        | 0.000635    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0404     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 560         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 918         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 82.1          |
# |    ep_rew_mean          | 34            |
# | time/                   |               |
# |    fps                  | 1431          |
# |    iterations           | 10            |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00066329853 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.0045        |
# |    learning_rate        | 0.0001        |
# |    loss                 | 853           |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.00268      |
# |    value_loss           | 2.46e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79.9         |
# |    ep_rew_mean          | 38.7         |
# | time/                   |              |
# |    fps                  | 1460         |
# |    iterations           | 11           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0054281275 |
# |    clip_fraction        | 0.00737      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0884       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 433          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00671     |
# |    value_loss           | 954          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.6        |
# |    ep_rew_mean          | 38.9        |
# | time/                   |             |
# |    fps                  | 1431        |
# |    iterations           | 12          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.004059409 |
# |    clip_fraction        | 0.00146     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0469      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 203         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00571    |
# |    value_loss           | 693         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.5         |
# |    ep_rew_mean          | 46.1         |
# | time/                   |              |
# |    fps                  | 1400         |
# |    iterations           | 13           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0034338129 |
# |    clip_fraction        | 0.00498      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00893      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 359          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00586     |
# |    value_loss           | 500          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82           |
# |    ep_rew_mean          | 63.2         |
# | time/                   |              |
# |    fps                  | 1392         |
# |    iterations           | 14           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0030837501 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 263          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 591          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.3         |
# |    ep_rew_mean          | 71.8         |
# | time/                   |              |
# |    fps                  | 1418         |
# |    iterations           | 15           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0027935694 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00233     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 219          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00467     |
# |    value_loss           | 730          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 81.4       |
# |    ep_rew_mean          | 77.1       |
# | time/                   |            |
# |    fps                  | 1420       |
# |    iterations           | 16         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00297448 |
# |    clip_fraction        | 0.000928   |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | -0.186     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 340        |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0027    |
# |    value_loss           | 488        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.7         |
# |    ep_rew_mean          | 77.7         |
# | time/                   |              |
# |    fps                  | 1439         |
# |    iterations           | 17           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0050918786 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.0474      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 179          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00581     |
# |    value_loss           | 434          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87           |
# |    ep_rew_mean          | 70.7         |
# | time/                   |              |
# |    fps                  | 1456         |
# |    iterations           | 18           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0059071393 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.0134      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 181          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 353          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85           |
# |    ep_rew_mean          | 70.5         |
# | time/                   |              |
# |    fps                  | 1425         |
# |    iterations           | 19           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0009329114 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.0188       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 320          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00457     |
# |    value_loss           | 1.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84           |
# |    ep_rew_mean          | 65.3         |
# | time/                   |              |
# |    fps                  | 1439         |
# |    iterations           | 20           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0017767382 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.107       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 314          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00216     |
# |    value_loss           | 420          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 76.8         |
# |    ep_rew_mean          | 67.3         |
# | time/                   |              |
# |    fps                  | 1407         |
# |    iterations           | 21           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0028910202 |
# |    clip_fraction        | 0.00317      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.0281      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 434          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00343     |
# |    value_loss           | 623          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.9        |
# |    ep_rew_mean          | 79          |
# | time/                   |             |
# |    fps                  | 1423        |
# |    iterations           | 22          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004906467 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.0024     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 301         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00512    |
# |    value_loss           | 419         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.3        |
# |    ep_rew_mean          | 76.2        |
# | time/                   |             |
# |    fps                  | 1436        |
# |    iterations           | 23          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008028904 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.00738     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 137         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00656    |
# |    value_loss           | 292         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.6         |
# |    ep_rew_mean          | 70.4         |
# | time/                   |              |
# |    fps                  | 1405         |
# |    iterations           | 24           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0018268127 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.063        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 160          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 328          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.8         |
# |    ep_rew_mean          | 77.7         |
# | time/                   |              |
# |    fps                  | 1411         |
# |    iterations           | 25           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0050985534 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00652     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 223          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00961     |
# |    value_loss           | 421          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | 75.8        |
# | time/                   |             |
# |    fps                  | 1414        |
# |    iterations           | 26          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004783579 |
# |    clip_fraction        | 0.0224      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.0197     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 86.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00455    |
# |    value_loss           | 303         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | 73.5         |
# | time/                   |              |
# |    fps                  | 1421         |
# |    iterations           | 27           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0054391883 |
# |    clip_fraction        | 0.00674      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.00237     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 75.4         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00529     |
# |    value_loss           | 222          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | 76.7         |
# | time/                   |              |
# |    fps                  | 1415         |
# |    iterations           | 28           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0013552037 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.0526       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 191          |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 393          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 81.1        |
# | time/                   |             |
# |    fps                  | 1414        |
# |    iterations           | 29          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004164336 |
# |    clip_fraction        | 0.00229     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.0162     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 156         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00443    |
# |    value_loss           | 335         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | 77.1        |
# | time/                   |             |
# |    fps                  | 1421        |
# |    iterations           | 30          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.005375864 |
# |    clip_fraction        | 0.0139      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.0039     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 96.6        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00503    |
# |    value_loss           | 196         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.7        |
# |    ep_rew_mean          | 78.3        |
# | time/                   |             |
# |    fps                  | 1428        |
# |    iterations           | 31          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009503035 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.000287   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 177         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00927    |
# |    value_loss           | 299         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | 72.8         |
# | time/                   |              |
# |    fps                  | 1431         |
# |    iterations           | 32           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0017980956 |
# |    clip_fraction        | 0.000342     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.0555       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 206          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00292     |
# |    value_loss           | 394          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 105          |
# |    ep_rew_mean          | 69.4         |
# | time/                   |              |
# |    fps                  | 1437         |
# |    iterations           | 33           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0036124247 |
# |    clip_fraction        | 0.0021       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.00137     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 240          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00484     |
# |    value_loss           | 476          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.2         |
# |    ep_rew_mean          | 69.4         |
# | time/                   |              |
# |    fps                  | 1442         |
# |    iterations           | 34           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0028795935 |
# |    clip_fraction        | 0.00142      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.00676     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 181          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 347          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.9        |
# |    ep_rew_mean          | 64          |
# | time/                   |             |
# |    fps                  | 1446        |
# |    iterations           | 35          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004766902 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.0117     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 257         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 510         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 85.6          |
# |    ep_rew_mean          | 63.9          |
# | time/                   |               |
# |    fps                  | 1436          |
# |    iterations           | 36            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.00082042115 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 0.053         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 97            |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.00274      |
# |    value_loss           | 449           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.3         |
# |    ep_rew_mean          | 66.1         |
# | time/                   |              |
# |    fps                  | 1430         |
# |    iterations           | 37           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0030667153 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.0584       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 157          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00388     |
# |    value_loss           | 358          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.6         |
# |    ep_rew_mean          | 65.8         |
# | time/                   |              |
# |    fps                  | 1432         |
# |    iterations           | 38           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0027535583 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.0279      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 146          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00487     |
# |    value_loss           | 376          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.9        |
# |    ep_rew_mean          | 73.2        |
# | time/                   |             |
# |    fps                  | 1423        |
# |    iterations           | 39          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005161212 |
# |    clip_fraction        | 0.00176     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.00482    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 156         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00496    |
# |    value_loss           | 314         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88.5         |
# |    ep_rew_mean          | 75.1         |
# | time/                   |              |
# |    fps                  | 1417         |
# |    iterations           | 40           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0012753578 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.00251     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 170          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 315          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84           |
# |    ep_rew_mean          | 79.8         |
# | time/                   |              |
# |    fps                  | 1422         |
# |    iterations           | 41           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0035515546 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.00493     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 182          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0041      |
# |    value_loss           | 442          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 78.1       |
# |    ep_rew_mean          | 80.9       |
# | time/                   |            |
# |    fps                  | 1425       |
# |    iterations           | 42         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.00069101 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.132      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 215        |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0025    |
# |    value_loss           | 467        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88          |
# |    ep_rew_mean          | 78.3        |
# | time/                   |             |
# |    fps                  | 1412        |
# |    iterations           | 43          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004255465 |
# |    clip_fraction        | 0.0019      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.00225    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 232         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00401    |
# |    value_loss           | 352         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.3         |
# |    ep_rew_mean          | 80.1         |
# | time/                   |              |
# |    fps                  | 1405         |
# |    iterations           | 44           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0060509094 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.0404      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 95.5         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00611     |
# |    value_loss           | 256          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 88.6      |
# |    ep_rew_mean          | 81.1      |
# | time/                   |           |
# |    fps                  | 1387      |
# |    iterations           | 45        |
# |    time_elapsed         | 66        |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0056954 |
# |    clip_fraction        | 0.0137    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32     |
# |    explained_variance   | -0.00859  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 164       |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.00718  |
# |    value_loss           | 335       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.8         |
# |    ep_rew_mean          | 81.2         |
# | time/                   |              |
# |    fps                  | 1378         |
# |    iterations           | 46           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0020237034 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.021        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 100          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 324          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.2         |
# |    ep_rew_mean          | 81.5         |
# | time/                   |              |
# |    fps                  | 1375         |
# |    iterations           | 47           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0061725825 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.00998     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 221          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00373     |
# |    value_loss           | 277          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.9         |
# |    ep_rew_mean          | 85.2         |
# | time/                   |              |
# |    fps                  | 1368         |
# |    iterations           | 48           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0059554977 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.0192      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 138          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0072      |
# |    value_loss           | 273          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.3        |
# |    ep_rew_mean          | 86.7        |
# | time/                   |             |
# |    fps                  | 1355        |
# |    iterations           | 49          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.002915014 |
# |    clip_fraction        | 0.0085      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.0139     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 132         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00424    |
# |    value_loss           | 257         |
# -----------------------------------------

# %% [markdown]
# Test the network:

# %%
model = PPO.load("ppo_gridworld")

gridworld_env = GridworldEnv(grid_size=5)


# Test the trained model
obs = gridworld_env.reset()

while True:
    action, _states = model.predict(obs)
    obs, reward, done, _ = gridworld_env.step(action)
    gridworld_env.render()
    if done:
        break

pygame.quit()
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
